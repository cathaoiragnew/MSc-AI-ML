# %% [markdown]
# Name:    David Cherry,        ID: 13056212
#
# Name:    Cathaoir Agnew,    ID: 16171659
#
# Name:    Conor O’Donovan,     ID: 9730761

# %% [markdown]
# Below is for uploading the excel files of each controller run into python, so we can then save to data frame. Need to upload control_runs excel

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3bb8eecc-9dfa-43ae-924b-a7073099d5d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bb8eecc-9dfa-43ae-924b-a7073099d5d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving control_runs.xlsx to control_runs.xlsx

# %% [markdown]
# read into dataframes

# %% [markdown]
# # **Nearest Pill Controller**
# *******************************

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import math


# nearest pill controller
df_NearPill = pd.read_excel('control_runs.xlsx' , sheet_name='NearestPillPacMan')
df_NearPill.head()
# Out:
#    Score  Time  Level         Controller
# 0   2660  1302      2  NearestPillPacMan
# 1   3020  1375      2  NearestPillPacMan
# 2   2010  1038      1  NearestPillPacMan
# 3   1980  1014      1  NearestPillPacMan
# 4   2050  1055      1  NearestPillPacMan

# %%
# seperate cells cause it looks better/ easy to follow 
df_NearPill.describe()
# Out:
#             Score         Time        Level
# count  1000.00000  1000.000000  1000.000000
# mean   2376.58000  1134.101000     1.315000
# std     571.34012   165.520173     0.469036
# min    1350.00000   712.000000     1.000000
# 25%    2020.00000  1040.000000     1.000000
# 50%    2080.00000  1056.000000     1.000000
# 75%    2840.00000  1265.250000     2.000000
# max    7230.00000  3085.000000     3.000000

# %%
mean_score = df_NearPill['Score'].mean()
std_score = df_NearPill['Score'].std()
max_score = df_NearPill['Score'].max()
min_score = df_NearPill['Score'].min()

print(mean_score)
print(std_score)
print(max_score)
print(min_score)
# Out:
# 2376.58
# 571.340120360135
# 7230
# 1350

# %% [markdown]
# # **Starter Pac man Controller**
# *******************************

# %%
# starter pac man controller
df_Starter = pd.read_excel('control_runs.xlsx' , sheet_name='StarterPacMan')
df_Starter.head()
# Out:
#    Score  Time  Level     Controller
# 0   2670   915      1  StarterPacMan
# 1   2330   564      1  StarterPacMan
# 2   1980   831      1  StarterPacMan
# 3   3260   796      1  StarterPacMan
# 4   3350   971      1  StarterPacMan

# %%
# seperate cells cause it looks better/ easy to follow 
df_Starter.describe()
# Out:
#              Score         Time        Level
# count  1000.000000  1000.000000  1000.000000
# mean   3328.080000   848.333000     1.001000
# std    1686.310101   256.691368     0.031623
# min     920.000000   486.000000     1.000000
# 25%    2330.000000   625.000000     1.000000
# 50%    2670.000000   804.500000     1.000000
# 75%    4140.000000   992.250000     1.000000
# max    9840.000000  2258.000000     2.000000

# %% [markdown]
# # **Random pac man Controller**
# *******************************

# %%
# random pac man controller
df_Rand = pd.read_excel('control_runs.xlsx' , sheet_name='RandomPacMan')
df_Rand.head()
# Out:
#    Score  Time  Level    Controller
# 0    140   416      1  RandomPacMan
# 1    100   487      1  RandomPacMan
# 2    140   476      1  RandomPacMan
# 3    270   532      1  RandomPacMan
# 4    190   446      1  RandomPacMan

# %%
# seperate cells cause it looks better/ easy to follow 
df_Rand.describe()
# Out:
#              Score         Time   Level
# count  1000.000000  1000.000000  1000.0
# mean    195.050000   487.661000     1.0
# std      69.235765    82.368141     0.0
# min      50.000000   371.000000     1.0
# 25%     150.000000   440.000000     1.0
# 50%     180.000000   468.000000     1.0
# 75%     230.000000   511.000000     1.0
# max     540.000000  1102.000000     1.0

# %% [markdown]
# # **Random no reverse Controller**
# *******************************

# %%
df_RandNon = pd.read_excel('control_runs.xlsx' , sheet_name='RandomNonRevPacMan')
df_RandNon.head()
# Out:
#    Score  Time  Level          Controller
# 0   1040   972      1  RandomNonRevPacMan
# 1    620   403      1  RandomNonRevPacMan
# 2    840   734      1  RandomNonRevPacMan
# 3   1340   958      1  RandomNonRevPacMan
# 4   1630   783      1  RandomNonRevPacMan

# %%
# seperate cells cause it looks better/ easy to follow 
df_RandNon.describe()
# Out:
#              Score         Time   Level
# count  1000.000000  1000.000000  1000.0
# mean   1178.410000   906.617000     1.0
# std     570.590523   369.964715     0.0
# min     210.000000   291.000000     1.0
# 25%     800.000000   643.000000     1.0
# 50%    1050.000000   863.000000     1.0
# 75%    1380.000000  1107.500000     1.0
# max    4480.000000  2859.000000     1.0

# %% [markdown]
# # **Custom Controller**
# *******************************

# %%
df_Custom = pd.read_excel('control_runs.xlsx' , sheet_name='CustomPacMan')
df_Custom.head()
# Out:
#    Score  Time  Level    Controller
# 0   6010  2285      2  CustomPacMan
# 1   7320  3502      3  CustomPacMan
# 2  11740  4317      3  CustomPacMan
# 3   8380  2301      2  CustomPacMan
# 4   5120  2835      2  CustomPacMan

# %%
# seperate cells cause it looks better/ easy to follow 
df_Custom.describe()
# Out:
#               Score         Time        Level
# count   1000.000000  1000.000000  1000.000000
# mean    6182.880000  2740.739000     2.088000
# std     2766.479299  1063.832178     0.822759
# min     1270.000000   953.000000     1.000000
# 25%     4152.500000  1869.250000     1.000000
# 50%     6130.000000  2637.000000     2.000000
# 75%     8080.000000  3415.000000     3.000000
# max    15700.000000  6479.000000     5.000000

# %%
print(df_Custom['Score'].median())
print(df_Custom['Score'].mean())
# Out:
# 6130.0
# 6182.88

# %% [markdown]
# https://towardsdatascience.com/histograms-and-density-plots-in-python-f6bda88f5ac0

# %%
 #Density Plot and Histogram of scores
sns.distplot(df_Custom['Score'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

plt.title("Custom Controller Scores Distrubtion")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
 #Density Plot and Histogram of scores
sns.distplot(df_Custom['Time'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

plt.title("Custom Controller Time Survived Distrubtion")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # **All Controllers Dataframe**
#
# **********************************************

# %%
df_all = pd.concat([df_Custom,df_NearPill,df_Rand,df_RandNon,df_Starter] , axis = 0)


print(df_all.head(10))
print("")
print(df_all.tail(10))
print("")
print(df_all.shape)
# Out:
#    Score  Time  Level    Controller
# 0   6010  2285      2  CustomPacMan
# 1   7320  3502      3  CustomPacMan
# 2  11740  4317      3  CustomPacMan
# 3   8380  2301      2  CustomPacMan
# 4   5120  2835      2  CustomPacMan
# 5   6230  3188      3  CustomPacMan
# 6   9260  4132      3  CustomPacMan
# 7   6150  2767      2  CustomPacMan
# 8   2540  1156      1  CustomPacMan
# 9   6470  2445      2  CustomPacMan
#
#      Score  Time  Level     Controller
# 990   2420   600      1  StarterPacMan
# 991   3760  1278      1  StarterPacMan
# 992   2580   798      1  StarterPacMan
# 993   1740   709      1  StarterPacMan
# 994   6450   954      1  StarterPacMan
# 995   3130   719      1  StarterPacMan
# 996   1590   565      1  StarterPacMan
# 997   5590  1280      1  StarterPacMan
# 998   3330   946      1  StarterPacMan
# 999   3220   967      1  StarterPacMan
#
# (5000, 4)

# %% [markdown]
# # **Used Resources**
# **********************************
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html
#
#
# https://stackoverflow.com/questions/53519823/confidence-interval-in-python-dataframe

# %%
#stats_score = df_all.groupby(['Controller'])['Score'].agg(['mean', 'min', 'max', 'std'])
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"


stats_score = df_all.groupby(['Controller'])['Score'].agg(['mean', 'count', 'std'])
print(stats_score)
print('-'*55)

ci95_hi = []
ci95_lo = []


for i in stats_score.index:
    m, c, s = stats_score.loc[i]
    ci95_hi.append(m + 1.96*s/math.sqrt(c))
    ci95_lo.append(m - 1.96*s/math.sqrt(c))

stats_score['ci95_lo'] = ci95_lo
stats_score['ci95_hi'] = ci95_hi


stats_score['min'] = df_all.groupby(['Controller'])['Score'].min()
stats_score['max'] = df_all.groupby(['Controller'])['Score'].max()
stats_score['median'] = df_all.groupby(['Controller'])['Score'].median()
stats_score['var'] = df_all.groupby(['Controller'])['Score'].var()

display(stats_score)
# Out:
#                        mean  count          std
# Controller
# CustomPacMan        6182.88   1000  2766.479299
# NearestPillPacMan   2376.58   1000   571.340120
# RandomNonRevPacMan  1178.41   1000   570.590523
# RandomPacMan         195.05   1000    69.235765
# StarterPacMan       3328.08   1000  1686.310101
# -------------------------------------------------------
#                        mean  count          std  ...    max  median           var
# Controller                                       ...
# CustomPacMan        6182.88   1000  2766.479299  ...  15700    6130  7.653408e+06
# NearestPillPacMan   2376.58   1000   571.340120  ...   7230    2080  3.264295e+05
# RandomNonRevPacMan  1178.41   1000   570.590523  ...   4480    1050  3.255735e+05
# RandomPacMan         195.05   1000    69.235765  ...    540     180  4.793591e+03
# StarterPacMan       3328.08   1000  1686.310101  ...   9840    2670  2.843642e+06
#
# [5 rows x 9 columns]

# %% [markdown]
# Median 95 % CI

# %%
stats_score_med = df_all.groupby(['Controller'])['Score'].agg(['median', 'count', 'std'])
print(stats_score_med)
print('-'*55)

ci95_hi_m = []
ci95_lo_m = []


for i in stats_score.index:
    m, c, s = stats_score_med.loc[i]
    ci95_hi_m.append(m + 1.96*s/math.sqrt(c))
    ci95_lo_m.append(m - 1.96*s/math.sqrt(c))

stats_score_med['ci95_lo'] = ci95_lo_m
stats_score_med['ci95_hi'] = ci95_hi_m

display(stats_score_med)
# Out:
#                     median  count          std
# Controller
# CustomPacMan          6130   1000  2766.479299
# NearestPillPacMan     2080   1000   571.340120
# RandomNonRevPacMan    1050   1000   570.590523
# RandomPacMan           180   1000    69.235765
# StarterPacMan         2670   1000  1686.310101
# -------------------------------------------------------
#                     median  count          std      ci95_lo      ci95_hi
# Controller
# CustomPacMan          6130   1000  2766.479299  5958.531837  6301.468163
# NearestPillPacMan     2080   1000   571.340120  2044.587972  2115.412028
# RandomNonRevPacMan    1050   1000   570.590523  1014.634433  1085.365567
# RandomPacMan           180   1000    69.235765   175.708723   184.291277
# StarterPacMan         2670   1000  1686.310101  2565.481417  2774.518583

# %%
stats_time = df_all.groupby(['Controller'])['Time'].agg(['mean', 'count', 'std'])
print(stats_time)
print('-'*55)

ci95_hi_time = []
ci95_lo_time = []


for i in stats_time.index:
    m, c, s = stats_time.loc[i]
    ci95_hi_time.append(m + 1.96*s/math.sqrt(c))
    ci95_lo_time.append(m - 1.96*s/math.sqrt(c))

stats_time['ci95_lo_time'] = ci95_lo_time
stats_time['ci95_hi_time'] = ci95_hi_time


stats_time['min'] = df_all.groupby(['Controller'])['Time'].min()
stats_time['max'] = df_all.groupby(['Controller'])['Time'].max()
stats_time['median'] = df_all.groupby(['Controller'])['Time'].median()

display(stats_time)
# Out:
#                         mean  count          std
# Controller
# CustomPacMan        2740.739   1000  1063.832178
# NearestPillPacMan   1134.101   1000   165.520173
# RandomNonRevPacMan   906.617   1000   369.964715
# RandomPacMan         487.661   1000    82.368141
# StarterPacMan        848.333   1000   256.691368
# -------------------------------------------------------
#                         mean  count          std  ...  min   max  median
# Controller                                        ...
# CustomPacMan        2740.739   1000  1063.832178  ...  953  6479  2637.0
# NearestPillPacMan   1134.101   1000   165.520173  ...  712  3085  1056.0
# RandomNonRevPacMan   906.617   1000   369.964715  ...  291  2859   863.0
# RandomPacMan         487.661   1000    82.368141  ...  371  1102   468.0
# StarterPacMan        848.333   1000   256.691368  ...  486  2258   804.5
#
# [5 rows x 8 columns]

# %% [markdown]
# Time 95% median CI

# %%
stats_score_med = df_all.groupby(['Controller'])['Time'].agg(['median', 'count', 'std'])
print(stats_score_med)
print('-'*55)

ci95_hi_m = []
ci95_lo_m = []


for i in stats_score.index:
    m, c, s = stats_score_med.loc[i]
    ci95_hi_m.append(m + 1.96*s/math.sqrt(c))
    ci95_lo_m.append(m - 1.96*s/math.sqrt(c))

stats_score_med['ci95_lo'] = ci95_lo_m
stats_score_med['ci95_hi'] = ci95_hi_m

display(stats_score_med)
# Out:
#                     median  count          std
# Controller
# CustomPacMan        2637.0   1000  1063.832178
# NearestPillPacMan   1056.0   1000   165.520173
# RandomNonRevPacMan   863.0   1000   369.964715
# RandomPacMan         468.0   1000    82.368141
# StarterPacMan        804.5   1000   256.691368
# -------------------------------------------------------
#                     median  count          std      ci95_lo      ci95_hi
# Controller
# CustomPacMan        2637.0   1000  1063.832178  2571.062998  2702.937002
# NearestPillPacMan   1056.0   1000   165.520173  1045.740953  1066.259047
# RandomNonRevPacMan   863.0   1000   369.964715   840.069349   885.930651
# RandomPacMan         468.0   1000    82.368141   462.894770   473.105230
# StarterPacMan        804.5   1000   256.691368   788.590104   820.409896

# %%
# this is discrete variable ie 1, 2 ,3       - we use count instead of mean, mean would be like 1.3 level which doesnt make sense

stats_level = df_all.groupby(['Controller' , 'Level'])['Level'].agg(['count'])
print(stats_level)
print('-'*55)
# Out:
#                           count
# Controller         Level
# CustomPacMan       1        258
#                    2        435
#                    3        269
#                    4         37
#                    5          1
# NearestPillPacMan  1        687
#                    2        311
#                    3          2
# RandomNonRevPacMan 1       1000
# RandomPacMan       1       1000
# StarterPacMan      1        999
#                    2          1
# -------------------------------------------------------

# %% [markdown]
# # **Data Viz stuff**
# ****************************************************

# %%
# box plot of scores 

fig, ax = plt.subplots(figsize=(8,8))

ax.boxplot(   [ df_NearPill["Score"], df_Starter["Score"], df_Rand["Score"], df_RandNon['Score'] , df_Custom["Score"] ] )

ax.set_xticklabels(["Nearest Pill", "Starter" , "Random" , "Random Non Reverse" , "Custom" ] , rotation = 90 )
ax.set_ylabel("Score")

ax.set_title("Box plots of Score")

plt.show()
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3db38421d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f3db3842be0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3db38506a0>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3db3850320>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3db38424e0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f3db380ac18>]}
# [Text(0, 0, 'Nearest Pill'),
#  Text(0, 0, 'Starter'),
#  Text(0, 0, 'Random'),
#  Text(0, 0, 'Random Non Reverse'),
#  Text(0, 0, 'Custom')]
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'Box plots of Score')

# %% [markdown]
# Box plot time

# %%
# box plot of scores 

fig, ax = plt.subplots(figsize=(8,8))

ax.boxplot(   [ df_NearPill["Time"], df_Starter["Time"], df_Rand["Time"], df_RandNon['Time'] , df_Custom["Time"] ] )

ax.set_xticklabels(["Nearest Pill", "Starter" , "Random" , "Random Non Reverse" , "Custom" ] , rotation = 90 )
ax.set_ylabel("Score")

ax.set_title("Box plots of Time Survived")

plt.show()
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3db3781fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f3db3792a20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3db379b4e0>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3db379b160>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3db3792320>,
# ...
#   <matplotlib.lines.Line2D at 0x7f3db3754a20>]}
# [Text(0, 0, 'Nearest Pill'),
#  Text(0, 0, 'Starter'),
#  Text(0, 0, 'Random'),
#  Text(0, 0, 'Random Non Reverse'),
#  Text(0, 0, 'Custom')]
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'Box plots of Time Survived')

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax = sns.countplot(x="Level", data=df_all ,hue="Controller")

ax.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))


count = 0
# label each bar in barplot
for p in ax.patches:  
  height = p.get_height()
  ax.text(x = p.get_x()+(p.get_width()/2), y = height+10, s = '{:.0f}'.format(height), ha = 'center', rotation = 90) 


plt.title("Bar plot of Level Counts")
plt.show()
# Out:
# Text(-0.32, 268.0, '258')
# Text(0.6799999999999999, 445.0, '435')
# Text(1.68, 279.0, '269')
# Text(2.68, 47.0, '37')
# Text(3.68, 11.0, '1')
# Text(-0.15999999999999998, 697.0, '687')
# Text(0.84, 321.0, '311')
# Text(1.84, 12.0, '2')
# Text(2.84, nan, 'nan')
# Text(3.84, nan, 'nan')
# Text(0.0, 1010.0, '1000')
# Text(1.0, nan, 'nan')
# Text(2.0, nan, 'nan')
# Text(3.0, nan, 'nan')
# Text(4.0, nan, 'nan')
# Text(0.15999999999999998, 1010.0, '1000')
# Text(1.16, nan, 'nan')
# Text(2.16, nan, 'nan')
# Text(3.16, nan, 'nan')
# Text(4.16, nan, 'nan')
# Text(0.32, 1009.0, '999')
# Text(1.32, 11.0, '1')
# Text(2.32, nan, 'nan')
# Text(3.32, nan, 'nan')
# Text(4.32, nan, 'nan')
# Text(0.5, 1.0, 'Bar plot of Level Counts')
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax = sns.countplot(x="Level", data=df_all ,hue="Controller")

ax.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))

plt.grid()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax = sns.countplot(x="Level", data=df_Custom , hue = 'Controller')

ax.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))

plt.title("Bar plot of Level Counts for Custom Controller")

plt.show()
# Out:
# Text(0.5, 1.0, 'Bar plot of Level Counts for Custom Controller')

# %% [markdown]
# # **Quick Look at Correlations of performance indicators**
# *************************************

# %%
corr = df_Custom.corr() 

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))


# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr)

# %%
plt.scatter(df_Custom['Time'], df_Custom['Score'])


plt.xlabel("Time Survived")
plt.ylabel("Score")

plt.title("Correlation of Time Survived vs Score")
plt.show()
# Out:
# Text(0.5, 0, 'Time Survived')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'Correlation of Time Survived vs Score')

# %%
plt.scatter(df_Custom['Level'], df_Custom['Score'])

plt.xlabel("Level Reached")
plt.ylabel("Score")

plt.title("Correlation of Level Reached vs Score")
plt.show()
# Out:
# Text(0.5, 0, 'Level Reached')
# Text(0, 0.5, 'Score')
# Text(0.5, 1.0, 'Correlation of Level Reached vs Score')

# %%
plt.scatter(df_Custom['Level'], df_Custom['Time'])

plt.xlabel("Level Reached")
plt.ylabel("Time Survived")

plt.title("Correlation of Level Reached vs Time Survived")
plt.show()
# Out:
# Text(0.5, 0, 'Level Reached')
# Text(0, 0.5, 'Time Survived')
# Text(0.5, 1.0, 'Correlation of Level Reached vs Time Survived')
